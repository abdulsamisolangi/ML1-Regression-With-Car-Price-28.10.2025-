# %%
#Student Details:

class student:
    def __init__(self,name=None,age=None,section=None,course=None):
        self.name=input("Enter Your Name:")
        self.age=input("Enter Your age:")
        self.section = input("Enter Your section:")
        self.course=input("Enter Your Course Name:")
        
        
    def student_details(self):    #method
        st=[self.name,self.age,self.section,self.course]
        print(st)

# %%
st1=student()
# Out:
# Enter Your Name: lala
# Enter Your age: 34
# Enter Your section: A
# Enter Your Course Name: Ai/Ml

# %%
st1.student_details()
# Out:
# ['lala', '34', 'A', 'Ai/Ml']

# %%
#Marksheet:

class student:
    def __init__(self,name=None,marks=None):
        self.name=input("Enter Your Name")
        self.marks=int(input("Enter Obtained marks:"))
    
    def __student_detail(self):
        print(f"{self.name} and {self.marks} and {grade}")
    
    def sheet(self):
        per=(self.marks*100)/1100
        print(per)
       
        if per>=80:
            print("Grade A+")
        elif per>=70:
            print("Grade A")
        elif per>=60:
            print("Grade B")
        elif per>=50:
            print("Grade C")
        else:
            print("Grade D, You are Fail")
            
stu=student()
stu.sheet()
# Out:
# Enter Your Name Asim
# Enter Obtained marks: 564
# 51.27272727272727
# Grade C

# %%
class Vehicle:
    def __init__(self,brand=None,name=None,type=None,price=None,delivery=None):
        self.brand=input("Enter Brand name:")
        self.name=input("Enter Vehicle name:")
        self.type=input("Enter type of Vehicle:")
        self.price=int(input("Enter Price of Vehicle:"))
        self.delivery=input("Enter Delivery time:")

    def Vehicle_details(self):    #method
        veh=[self.name,self.type,self.price,self.delivery]
        print(veh)

    
veh=Vehicle()
# Out:
# Enter Brand name: Corrola
# Enter Vehicle name: yaris
# Enter type of Vehicle: sedan
# Enter Price of Vehicle: 5600000
# Enter Delivery time: 3 months
