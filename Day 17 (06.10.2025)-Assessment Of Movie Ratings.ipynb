# %%
## Movie Ratings Aggregator & Simple Recommender (Noman & Abdul Sami):

# %%
Objective: Manage movies and user ratings, compute movie stats, and give simple personalized recommendations.
Mandatory features:
Classes: Movie (id,title,genres), User (id,name,ratings dict movie_id→rating), RatingSystem (movies dict, users dict).
Use lists/dicts for movies, users, and rating matrices (user→{movie:rating}).
Methods: add_movie, add_user, add_rating, get_movie_averages(), recommend_for_user(user_id, top_n).
Nested loops: compute per-movie averages by looping movies → loop users to sum ratings; for recommendations, for each candidate movie → loop other users to estimate score (collaborative step).
Nested decisions: handle cold-start (user or movie with no ratings) by falling back to genre/popularity; tie-breaking by recency or avg rating.
