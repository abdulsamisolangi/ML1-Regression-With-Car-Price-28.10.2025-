# %%
# !pip install seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_rows',500)  #Setting pd to display customized rows
pd.set_option('display.max_columns',500)   #Setting pd to display customized columns
pd.set_option('display.width',2)   #Setting pd to display customized width

# %%
df=pd.read_csv('Coaster Data.csv')

# %%
df
# Out:
#                                 coaster_name  \
# 0                         Switchback Railway
# 1                          Flip Flap Railway
# 2     Switchback Railway (Euclid Beach Park)
# 3               Loop the Loop (Coney Island)
# 4               Loop the Loop (Young's Pier)
# ...                                      ...
# 1082                 American Dreier Looping
# 1083               Pantheon (roller coaster)
# 1084               Tron Lightcycle Power Run
# 1085                                 Tumbili
# 1086          Wonder Woman Flight of Courage
#
#                     Length  \
# 0           600 ft (180 m)
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 1082    3,444 ft (1,050 m)
# 1083    3,328 ft (1,014 m)
# 1084  3,169.3 ft (966.0 m)
# 1085        770 ft (230 m)
# 1086    3,300 ft (1,000 m)
#
#                         Speed  \
# 0            6 mph (9.7 km/h)
# ...

# %% [markdown]
# ## Step1: Data Understanding
# - Dataframe Shape
# - head and tail
# - dtypes
# - describe

# %%
df.shape
# Out:
# (1087, 56)

# %%
df.head()
# Out:
#                              coaster_name  \
# 0                      Switchback Railway
# 1                       Flip Flap Railway
# 2  Switchback Railway (Euclid Beach Park)
# 3            Loop the Loop (Coney Island)
# 4            Loop the Loop (Young's Pier)
#
#            Length  \
# 0  600 ft (180 m)
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
#               Speed  \
# 0  6 mph (9.7 km/h)
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
#                          Location  \
# 0                    Coney Island
# 1                   Sea Lion Park
# 2  Cleveland, Ohio, United States
# 3                           Other
# 4                           Other
#
#     Status  \
# 0  Removed
# 1  Removed
# 2   Closed
# 3  Removed
# 4  Removed
#
#     Opening date  \
# 0  June 16, 1884
# 1           1895
# 2            NaN
# 3           1901
# 4           1901
#
#     Type  \
# 0   Wood
# 1   Wood
# ...

# %%
df.tail()
# Out:
#                         coaster_name  \
# 1082         American Dreier Looping
# 1083       Pantheon (roller coaster)
# 1084       Tron Lightcycle Power Run
# 1085                         Tumbili
# 1086  Wonder Woman Flight of Courage
#
#                     Length  \
# 1082    3,444 ft (1,050 m)
# 1083    3,328 ft (1,014 m)
# 1084  3,169.3 ft (966.0 m)
# 1085        770 ft (230 m)
# 1086    3,300 ft (1,000 m)
#
#                         Speed  \
# 1082         53 mph (85 km/h)
# 1083        73 mph (117 km/h)
# 1084  59.3[1] mph (95.4 km/h)
# 1085         34 mph (55 km/h)
# 1086         58 mph (93 km/h)
#
#                         Location  \
# 1082                       Other
# 1083  Busch Gardens Williamsburg
# 1084                       Other
# 1085              Kings Dominion
# 1086    Six Flags Magic Mountain
#
#                   Status  \
# 1082                 NaN
# 1083  Under construction
# 1084                 NaN
# 1085  Under construction
# 1086  Under construction
#
# ...

# %%
df.describe()
# Out:
#        Inversions  \
# count  932.000000
# mean     1.547210
# std      2.114073
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      3.000000
# max     14.000000
#
#        year_introduced  \
# count      1087.000000
# mean       1994.986201
# std          23.475248
# min        1884.000000
# 25%        1989.000000
# 50%        2000.000000
# 75%        2010.000000
# max        2022.000000
#
#          latitude  \
# count  812.000000
# mean    38.373484
# std     15.516596
# min    -48.261700
# 25%     35.031050
# 50%     40.289800
# 75%     44.799600
# max     63.230900
#
#         longitude  \
# count  812.000000
# mean   -41.595373
# std     72.285227
# min   -123.035700
# 25%    -84.552200
# 50%    -76.653600
# 75%      2.778100
# max    153.426500
#
#        speed1_value  \
# count    937.000000
# mean      53.850374
# std       23.385518
# min        5.000000
# 25%       40.000000
# 50%       50.000000
# 75%       63.000000
# max      240.000000
#
# ...

# %%
df.dtypes
# Out:
# coaster_name                      object
# Length                            object
# Speed                             object
# Location                          object
# Status                            object
# Opening date                      object
# Type                              object
# Manufacturer                      object
# Height restriction                object
# Model                             object
# Height                            object
# Inversions                       float64
# Lift/launch system                object
# Cost                              object
# Trains                            object
# Park section                      object
# Duration                          object
# Capacity                          object
# G-force                           object
# Designer                          object
# Max vertical angle                object
# Drop                              object
# Soft opening date                 object
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1087 entries, 0 to 1086
# Data columns (total 56 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   coaster_name                   1087 non-null   object
#  1   Length                         953 non-null    object
#  2   Speed                          937 non-null    object
#  3   Location                       1087 non-null   object
#  4   Status                         874 non-null    object
#  5   Opening date                   837 non-null    object
#  6   Type                           1087 non-null   object
#  7   Manufacturer                   1028 non-null   object
#  8   Height restriction             831 non-null    object
#  9   Model                          744 non-null    object
#  10  Height                         965 non-null    object
#  11  Inversions                     932 non-null    float64
# ...

# %% [markdown]
# ## Step 2: Data Preparation
# - Dropping irrelevant columns and rows
# - Identifying duplicated columns
# - Remaining Columns
# - Feature Creations

# %%
df.columns
# Out:
# Index(['coaster_name',
#        'Length',
#        'Speed',
#        'Location',
#        'Status',
#        'Opening date',
#        'Type',
#        'Manufacturer',
#        'Height restriction',
#        'Model',
#        'Height',
#        'Inversions',
#        'Lift/launch system',
#        'Cost',
#        'Trains',
#        'Park section',
#        'Duration',
#        'Capacity',
#        'G-force',
#        'Designer',
#        'Max vertical angle',
#        'Drop',
#        'Soft opening date',
#        'Fast Lane available',
#        'Replaced',
#        'Track layout',
#        'Fastrack available',
#        'Soft opening date.1',
#        'Closing date',
#        'Opened',
#        'Replaced by',
#        'Website',
#        'Flash Pass Available',
#        'Must transfer from wheelchair',
#        'Theme',
#        'Single rider line available',
#        'Restraint Style',
#        'Flash Pass available',
#        'Acceleration',
#        'Restraints',
# ...

# %%
#df.drop(['Opening Date'], axis=1)

# %%
df=df[['coaster_name','Location', 'Status', 'Manufacturer','year_introduced', 'latitude', 'longitude', 'Type_Main', 'opening_date_clean','speed_mph','height_ft', 'Inversions_clean', 'Gforce_clean']].copy()

# %%
df.shape
# Out:
# (1087, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1087 entries, 0 to 1086
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   coaster_name        1087 non-null   object
#  1   Location            1087 non-null   object
#  2   Status              874 non-null    object
#  3   Manufacturer        1028 non-null   object
#  4   year_introduced     1087 non-null   int64
#  5   latitude            812 non-null    float64
#  6   longitude           812 non-null    float64
#  7   Type_Main           1087 non-null   object
#  8   opening_date_clean  837 non-null    object
#  9   speed_mph           937 non-null    float64
#  10  height_ft           171 non-null    float64
#  11  Inversions_clean    1087 non-null   int64
#  12  Gforce_clean        362 non-null    float64
# dtypes: float64(5), int64(2), object(6)
# memory usage: 110.5+ KB

# %%
df['opening_date_clean']
# Out:
# 0       1884-06-16
# 1       1895-01-01
# 2              NaN
# 3       1901-01-01
# 4       1901-01-01
#            ...
# 1082           NaN
# 1083    2022-01-01
# 1084    2016-06-16
# 1085           NaN
# 1086    2022-01-01
# Name: opening_date_clean, Length: 1087, dtype: object

# %%
df['opening_date_clean']=pd.to_datetime(df['opening_date_clean']) #to clean NaN Values from column
df
# Out:
#                                 coaster_name  \
# 0                         Switchback Railway
# 1                          Flip Flap Railway
# 2     Switchback Railway (Euclid Beach Park)
# 3               Loop the Loop (Coney Island)
# 4               Loop the Loop (Young's Pier)
# ...                                      ...
# 1082                 American Dreier Looping
# 1083               Pantheon (roller coaster)
# 1084               Tron Lightcycle Power Run
# 1085                                 Tumbili
# 1086          Wonder Woman Flight of Courage
#
#                             Location  \
# 0                       Coney Island
# 1                      Sea Lion Park
# 2     Cleveland, Ohio, United States
# 3                              Other
# 4                              Other
# ...                              ...
# 1082                           Other
# 1083      Busch Gardens Williamsburg
# 1084                           Other
# ...

# %% [markdown]
# ## Renaming Coulumns:

# %%
df.columns
# Out:
# Index(['coaster_name',
#        'Location',
#        'Status',
#        'Manufacturer',
#        'year_introduced',
#        'latitude',
#        'longitude',
#        'Type_Main',
#        'opening_date_clean',
#        'speed_mph',
#        'height_ft',
#        'Inversions_clean',
#        'Gforce_clean'],
#       dtype='object')

# %%
df=df.rename(columns={'Gforce_clean':'GForce','Inversions_clean':'Inversion','year_introduced':'Year','height_ft':'height'})
df
# Out:
#                                 coaster_name  \
# 0                         Switchback Railway
# 1                          Flip Flap Railway
# 2     Switchback Railway (Euclid Beach Park)
# 3               Loop the Loop (Coney Island)
# 4               Loop the Loop (Young's Pier)
# ...                                      ...
# 1082                 American Dreier Looping
# 1083               Pantheon (roller coaster)
# 1084               Tron Lightcycle Power Run
# 1085                                 Tumbili
# 1086          Wonder Woman Flight of Courage
#
#                             Location  \
# 0                       Coney Island
# 1                      Sea Lion Park
# 2     Cleveland, Ohio, United States
# 3                              Other
# 4                              Other
# ...                              ...
# 1082                           Other
# 1083      Busch Gardens Williamsburg
# 1084                           Other
# ...

# %%
df.isna().sum() #To see na values in columns
# Out:
# coaster_name            0
# Location                0
# Status                213
# Manufacturer           59
# Year                    0
# latitude              275
# longitude             275
# Type_Main               0
# opening_date_clean    250
# speed_mph             150
# height                916
# Inversion               0
# GForce                725
# dtype: int64

# %%
df.loc[df.duplicated()]  #To check duplicated values in columns
# Out:
# Empty DataFrame
# Columns: [coaster_name, Location, Status, Manufacturer, Year, latitude, longitude, Type_Main, opening_date_clean, speed_mph, height, Inversion, GForce]
# Index: []

# %% [markdown]
# ## To check duplicated coaster name:

# %%
df.loc[df.duplicated(subset=['coaster_name'])]
# Out:
#                                          coaster_name  \
# 43                              Crystal Beach Cyclone
# 60                                        Derby Racer
# 61                        Blue Streak (Conneaut Lake)
# 167                     Big Thunder Mountain Railroad
# 237                 Thunder Run (Canada's Wonderland)
# 239                                         La Vibora
# 241                     Big Thunder Mountain Railroad
# 252                                         La Vibora
# 262              Flashback (Six Flags Magic Mountain)
# 270                                    Alpine Bobsled
# 282                Ultra Twister (Nagashima Spa Land)
# 296                         Ultra Twister (Six Flags)
# 313                     Big Thunder Mountain Railroad
# 320              Flashback (Six Flags Magic Mountain)
# 332                                  Batman: The Ride
# 341                                   Lightnin' Loops
# ...

# %% [markdown]
# ## To check an example of duplicate

# %%
df.query('coaster_name == "Crystal Beach Cyclone"') #always use " in which we want to check and ' to column
# Out:
#              coaster_name  \
# 39  Crystal Beach Cyclone
# 43  Crystal Beach Cyclone
#
#               Location  \
# 39  Crystal Beach Park
# 43  Crystal Beach Park
#
#      Status  \
# 39  Removed
# 43  Removed
#
#           Manufacturer  \
# 39  Traver Engineering
# 43  Traver Engineering
#
#     Year  \
# 39  1926
# 43  1927
#
#     latitude  \
# 39   42.8617
# 43   42.8617
#
#     longitude  \
# 39   -79.0598
# 43   -79.0598
#
#    Type_Main  \
# 39      Wood
# 43      Wood
#
#    opening_date_clean  \
# 39         1926-01-01
# 43         1926-01-01
#
#     speed_mph  \
# 39       60.0
# 43       60.0
#
#     height  \
# 39     NaN
# 43     NaN
#
#     Inversion  \
# 39          0
# 43          0
#
#     GForce
# 39     4.0
# 43     4.0

# %%
df.query('Manufacturer == "Traver Engineering"')
# Out:
#                           coaster_name  \
# 34              Cyclone (Revere Beach)
# 36                        Jazz Railway
# 38            Thunderbolt (Savin Rock)
# 39               Crystal Beach Cyclone
# 40            Sesquicentennial Cyclone
# 43               Crystal Beach Cyclone
# 44  Cyclone (Palisades Amusement Park)
# 45            Lightning (Revere Beach)
# 48                Zip (roller coaster)
#
#                        Location  \
# 34                 Revere Beach
# 36              Rocky Glen Park
# 38                   Savin Rock
# 39           Crystal Beach Park
# 40  Sesquicentennial Exposition
# 43           Crystal Beach Park
# 44     Palisades Amusement Park
# 45                 Revere Beach
# 48          Oaks Amusement Park
#
#      Status  \
# 34  Removed
# 36  Removed
# 38  Removed
# 39  Removed
# 40  Removed
# 43  Removed
# 44  Removed
# 45  Removed
# 48  Removed
#
#           Manufacturer  \
# 34  Traver Engineering
# 36  Traver Engineering
# ...

# %%
df.query('Year == 2010') #when checking for integer we dont use Double Qoutation "
# Out:
#                                 coaster_name  \
# 805                               Air Grover
# 806    Battlestar Galactica (roller coaster)
# 807                             Canopy Flyer
# 808                         Dragon Challenge
# 809                        Ednör – L'Attaque
# 810                        Enchanted Airways
# 811                     Fiorano GT Challenge
# 812                            Formula Rossa
# 813                       Huracan (Belantis)
# 814             Intimidator (roller coaster)
# 815                          Intimidator 305
# 816                        Joris en de Draak
# 817  Little Dipper (Six Flags Great America)
# 818             The Monster (Walygator Parc)
# 819                            Raptor Attack
# 820                                 RC Racer
# 821                     Revenge of the Mummy
# 822                               Sky Rocket
# 823                 Space Fantasy – The Ride
# 824                Thirteen (roller coaster)
# ...

# %%
df=df.loc[~df.duplicated(subset=['coaster_name','Location','Status'])].reset_index(drop=True).copy() 
df  #~ it results boolean values i.e uniue/false
    #.reset_index(drop=True).copy() = it reset previously index in colum to new index
df.query('coaster_name == "Crystal Beach Cyclone"')
# Out:
#              coaster_name  \
# 39  Crystal Beach Cyclone
#
#               Location  \
# 39  Crystal Beach Park
#
#      Status  \
# 39  Removed
#
#           Manufacturer  \
# 39  Traver Engineering
#
#     Year  \
# 39  1926
#
#     latitude  \
# 39   42.8617
#
#     longitude  \
# 39   -79.0598
#
#    Type_Main  \
# 39      Wood
#
#    opening_date_clean  \
# 39         1926-01-01
#
#     speed_mph  \
# 39       60.0
#
#     height  \
# 39     NaN
#
#     Inversion  \
# 39          0
#
#     GForce
# 39     4.0

# %%
df.isna().sum()
# Out:
# coaster_name            0
# Location                0
# Status                146
# Manufacturer           58
# Year                    0
# latitude              207
# longitude             207
# Type_Main               0
# opening_date_clean    183
# speed_mph             140
# height                831
# Inversion               0
# GForce                666
# dtype: int64

# %% [markdown]
# ## Step 3. Feautre Understanding (Unvariate Analysis)  #17.10.2025
# ## - Plotting Feature Distribution
#      . Histogram
#      . KDE
#      . BOX Plot

# %%
df.columns
# Out:
# Index(['coaster_name',
#        'Location',
#        'Status',
#        'Manufacturer',
#        'Year',
#        'latitude',
#        'longitude',
#        'Type_Main',
#        'opening_date_clean',
#        'speed_mph',
#        'height',
#        'Inversion',
#        'GForce'],
#       dtype='object')

# %%
df['Year'].value_counts()
# Out:
# Year
# 1999    46
# 2000    45
# 1998    30
# 2001    29
# 2002    28
# 2008    27
# 2004    25
# 2011    24
# 2007    24
# 2013    23
# 2012    23
# 2006    23
# 1996    23
# 2014    22
# 1995    22
# 2015    22
# 2003    21
# 1997    21
# 2009    21
# 2005    20
# 2019    19
# 2010    19
# 2018    18
# 2016    17
# 2017    17
# 1992    17
# 1994    16
# 1976    16
# 1985    15
# 1993    14
# 1988    14
# 1984    13
# 1991    13
# 1990    13
# 1989    13
# 1987    13
# 1978    12
# 2022    12
# 2021    12
# 1983    11
# 1981    11
# 2020    10
# 1979     9
# 1980     8
# 1982     7
# 1975     7
# 1972     7
# 1925     6
# 1927     6
# 1977     6
# 1924     5
# 1974     5
# 1986     5
# 1970     4
# 1969     3
# 1958     3
# 1926     3
# 1951     3
# 1920     3
# 1971     3
# 1973     3
# 1964     3
# 1966     3
# 1902     2
# 1901     2
# 1923     2
# 1968     2
# 1928     2
# 1913     2
# 1930     2
# 1912     2
# 1967     2
# 1935     2
# 1909     2
# 1940     2
# 1941     2
# ...

# %% [markdown]
# ## Top 10 Year:

# %%
ax=df['Year'].value_counts().head(10).plot(kind='bar', title="Top 10 Year Coasters Introduced",xlabel='Year',ylabel='Count')

# %%
ax = df['speed_mph'].plot(kind='hist',bins=20,title = 'Coaster speed(mph)')

# %%
df['speed_mph'].unique()
# Out:
# array([  6. ,   nan,  10. ,  40. ,  37.3,  53. ,  45. ,  42. ,  35. ,
#         50. ,  55. ,  32. ,  48. ,  60. ,  31. ,  58. ,  25. ,  49.7,
#         27. ,  29. ,  14. ,  44.7,  31.1,  37. ,  46. ,  30. ,  57. ,
#         56. ,  36. ,   5. ,  62. ,  32.9,  64.8,  46.6,  41. ,  66. ,
#         34. ,  52. ,  34.8,  16.2,  55.9,  39.8,  51. ,  43.5,  40.4,
#         54.1,  17. ,  28. ,  47. ,  16.8,  34.1,  22.4,  59.7,  29.8,
#         47.8,  44. ,  68.3,  28.9,  65. ,  54.5,  68. ,  72. ,  54.7,
#         23. ,  24.9,  70. ,  34.2,  85. ,  35.4,  15. ,  56.5,  62.1,
#         21.7,  18.6,  80. ,  48.5,  66.5,  50.3,  74. ,  71.5,  52.4,
#         52.8,  43. ,  50.2,  54. ,  81. ,  33. ,  27.7,  75. ,  67. ,
#         63. , 100. ,  68.4,  50.5,   8. ,  73. ,  61. ,  29.1,  11. ,
#         16. ,  76. ,  41.2,  64. ,  66.3,  28.5,  59. ,  93. ,  78.4,
#         95. ,  77. ,  57.2,  13. ,  65.6, 111.8,  74.6,  26. ,  53.4,
# ...

# %%
df[df['speed_mph']<=50].count()
# Out:
# coaster_name          478
# Location              478
# Status                388
# Manufacturer          466
# Year                  478
# latitude              358
# longitude             358
# Type_Main             478
# opening_date_clean    380
# speed_mph             478
# height                 78
# Inversion             478
# GForce                151
# dtype: int64

# %%
df.isna().sum()
# Out:
# coaster_name            0
# Location                0
# Status                146
# Manufacturer           58
# Year                    0
# latitude              207
# longitude             207
# Type_Main               0
# opening_date_clean    183
# speed_mph             140
# height                831
# Inversion               0
# GForce                666
# dtype: int64

# %%
# !pip install scipy

# %%
# !pip install kde

# %%
ax = df['speed_mph'].plot(kind='kde',title = 'Coaster speed(mph)')

# %%
df.columns
# Out:
# Index(['coaster_name',
#        'Location',
#        'Status',
#        'Manufacturer',
#        'Year',
#        'latitude',
#        'longitude',
#        'Type_Main',
#        'opening_date_clean',
#        'speed_mph',
#        'height',
#        'Inversion',
#        'GForce'],
#       dtype='object')

# %%
df['coaster_name'].unique()
# Out:
# array(['Switchback Railway', 'Flip Flap Railway',
#        'Switchback Railway (Euclid Beach Park)',
#        'Loop the Loop (Coney Island)', "Loop the Loop (Young's Pier)",
#        'Cannon Coaster', 'Leap-The-Dips',
#        'Figure Eight (Euclid Beach Park)', 'Drop the Dip',
#        'Scenic Railway (Euclid Beach Park)',
#        'Loop the Loop (Olentangy Park)', 'Aero Dips',
#        'Backety-Back Scenic Railway', 'Racer (1910 roller coaster)',
#        'Derby Racer', 'The Great Scenic Railway', 'Zippin Pippin',
#        'Racing Coaster', 'Whirl Pool Dips',
#        'Green Dragon (Lake Compounce)', 'The Wild One (roller coaster)',
#        'Jack Rabbit (Clementon Park)', 'Jack Rabbit (Kennywood)',
#        'Jack Rabbit (Seabreeze)', 'Scenic Railway (roller coaster)',
#        'Roller Coaster (Lagoon)', 'Big Dipper (Blackpool Pleasure Beach)',
#        'Wild Cat (Hersheypark)', 'The Bobs (roller coaster)',
#        'Giant Dipper', 'Pippin (roller coaster)',
# ...

# %%
df['Type_Main']
# Out:
# 0       Wood
# 1       Wood
# 2      Other
# 3      Steel
# 4      Steel
#        ...
# 985    Steel
# 986     Wood
# 987    Steel
# 988    Steel
# 989    Steel
# Name: Type_Main, Length: 990, dtype: object

# %%
df['Type_Main'].unique
# Out:
# <bound method Series.unique of 0       Wood
# 1       Wood
# 2      Other
# 3      Steel
# 4      Steel
#        ...
# 985    Steel
# 986     Wood
# 987    Steel
# 988    Steel
# 989    Steel
# Name: Type_Main, Length: 990, dtype: object>

# %%
df['Type_Main'].value_counts()
# Out:
# Type_Main
# Steel    728
# Wood     191
# Other     71
# Name: count, dtype: int64

# %% [markdown]
# ## Step 4. Feature Relationship

# %%
df.columns
# Out:
# Index(['coaster_name',
#        'Location',
#        'Status',
#        'Manufacturer',
#        'Year',
#        'latitude',
#        'longitude',
#        'Type_Main',
#        'opening_date_clean',
#        'speed_mph',
#        'height',
#        'Inversion',
#        'GForce'],
#       dtype='object')

# %%
df.isna().sum()   #to see is there any na in column
# Out:
# coaster_name            0
# Location                0
# Status                146
# Manufacturer           58
# Year                    0
# latitude              207
# longitude             207
# Type_Main               0
# opening_date_clean    183
# speed_mph             140
# height                831
# Inversion               0
# GForce                666
# dtype: int64

# %%
df['Status'].unique()
# Out:
# array(['Removed', 'Closed', 'Operating', nan, 'Not Currently Operating',
#        'In Production', 'Discontinued',
#        'closed for maintenance as of july 30 no reopening date known',
#        'Closed in 2021', 'SBNO December 2019', 'Under construction',
#        'Temporarily Closed', 'SBNO (Standing But Not Operating)',
#        'Temporarily closed',
#        'Chapter 7 bankruptcy; rides dismantled and sold; property sold',
#        'Under Maintenance'], dtype=object)

# %%
df['Location']
# Out:
# 0                        Coney Island
# 1                       Sea Lion Park
# 2      Cleveland, Ohio, United States
# 3                               Other
# 4                               Other
#                     ...
# 985                  SeaWorld Orlando
# 986                         Sea World
# 987        Busch Gardens Williamsburg
# 988                    Kings Dominion
# 989          Six Flags Magic Mountain
# Name: Location, Length: 990, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 990 entries, 0 to 989
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   coaster_name        990 non-null    object
#  1   Location            990 non-null    object
#  2   Status              844 non-null    object
#  3   Manufacturer        932 non-null    object
#  4   Year                990 non-null    int64
#  5   latitude            783 non-null    float64
#  6   longitude           783 non-null    float64
#  7   Type_Main           990 non-null    object
#  8   opening_date_clean  807 non-null    datetime64[ns]
#  9   speed_mph           850 non-null    float64
#  10  height              159 non-null    float64
#  11  Inversion           990 non-null    int64
#  12  GForce              324 non-null    float64
# dtypes: datetime64[ns](1), float64(5), int64(2), object(5)
# memory usage: 100.7+ KB

# %%
df.plot(kind='scatter',x='speed_mph',y='GForce')
# Out:
# <Axes: xlabel='speed_mph', ylabel='GForce'>

# %%
df.plot(kind='scatter',x='speed_mph',y='latitude')
# Out:
# <Axes: xlabel='speed_mph', ylabel='latitude'>

# %%
df.plot(kind='scatter',x='GForce',y='longitude')
# Out:
# <Axes: xlabel='GForce', ylabel='longitude'>

# %%
ax=sns.scatterplot(x='speed_mph',y='height',hue='Year',data=df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 990 entries, 0 to 989
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   coaster_name        990 non-null    object
#  1   Location            990 non-null    object
#  2   Status              844 non-null    object
#  3   Manufacturer        932 non-null    object
#  4   Year                990 non-null    int64
#  5   latitude            783 non-null    float64
#  6   longitude           783 non-null    float64
#  7   Type_Main           990 non-null    object
#  8   opening_date_clean  807 non-null    datetime64[ns]
#  9   speed_mph           850 non-null    float64
#  10  height              159 non-null    float64
#  11  Inversion           990 non-null    int64
#  12  GForce              324 non-null    float64
# dtypes: datetime64[ns](1), float64(5), int64(2), object(5)
# memory usage: 100.7+ KB

# %%
sns.pairplot(df, vars=['Year','speed_mph','height','Inversion','GForce'],hue='Type_Main')
