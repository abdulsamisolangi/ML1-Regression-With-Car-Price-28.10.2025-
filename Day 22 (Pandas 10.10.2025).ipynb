# %% [markdown]
# ## Pandas:

# %%
# !pip install Pandas

# %%
import pandas as pd

# %%
df=pd.read_csv("cricinfo.csv")

# %%
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1    PHKD Mendis (SL)  2022-2025   12    21   2  1184  182*  62.31   1839
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 57   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 58  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 59  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 60    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 61   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s
# 0    58.6   29  13   7   626   6
# ...

# %%
import numpy as np
np.array(df)
# Out:
# array([['DG Bradman (AUS)', '1928-1948', 52, 80, 10, 6996, '334', 99.94,
#         '9800+', '58.6', 29, 13, '7', 626, 6],
#        ['PHKD Mendis (SL)', '2022-2025', 12, 21, 2, 1184, '182*', 62.31,
#         '1839', '64.38', 5, 4, '-', 123, 23],
#        ['AC Voges (AUS)', '2015-2016', 20, 31, 7, 1485, '269*', 61.87,
#         '2667', '55.68', 5, 4, '2', 186, 5],
#        ['RG Pollock (SA)', '1963-1970', 23, 41, 4, 2256, '274', 60.97,
#         '1707+', '54.48', 7, 11, '1', 246, 11],
#        ['GA Headley (WI)', '1930-1954', 22, 40, 4, 2190, '270*', 60.83,
#         '416+', '56', 10, 5, '2', 104, 1],
#        ['H Sutcliffe (ENG)', '1924-1935', 54, 84, 9, 4555, '194', 60.73,
#         '6558+', '34.59', 16, 23, '2', 202, 6],
#        ['E Paynter (ENG)', '1931-1939', 20, 31, 5, 1540, '243', 59.23,
#         '1288+', '45.88', 4, 7, '3', 125, 4],
#        ['KF Barrington (ENG)', '1955-1968', 82, 131, 15, 6806, '256',
#         58.67, '4957+', '42.42', 20, 35, '5', 591, 27],
# ...

# %%
df.columns     #df.columns = print(df.columns)
# Out:
# Index(['Player', 'Span', 'Mat', 'Inns', 'NO', 'Runs', 'HS', 'Ave', 'BF', 'SR',
#        '100', '50', '0', '4s', '6s'],
#       dtype='object')

# %%
df.rename(columns={'Mat':'Matches','Span':'Duration','NO':'Not Out','BF':'Ball Faced'}, inplace=True)
#'olderone':'newone'  #inplace=update'

# %%
df
# Out:
#                Player   Duration  Matches  Inns  Not Out  Runs    HS    Ave  \
# 0    DG Bradman (AUS)  1928-1948       52    80       10  6996   334  99.94
# 1    PHKD Mendis (SL)  2022-2025       12    21        2  1184  182*  62.31
# 2      AC Voges (AUS)  2015-2016       20    31        7  1485  269*  61.87
# 3     RG Pollock (SA)  1963-1970       23    41        4  2256   274  60.97
# 4     GA Headley (WI)  1930-1954       22    40        4  2190  270*  60.83
# ..                ...        ...      ...   ...      ...   ...   ...    ...
# 57   KD Walters (AUS)  1965-1981       74   125       14  5357   250  48.26
# 58  GC Smith (ICC/SA)  2002-2014      117   205       13  9265   277  48.25
# 59  WH Ponsford (AUS)  1924-1934       29    48        4  2122   266  48.22
# 60    SJ McCabe (AUS)  1930-1938       39    62        5  2748   232  48.21
# 61   DR Jardine (ENG)  1928-1934       22    33        6  1296   127  48.00
#
#    Ball Faced     SR  100  50   0    4s  6s
# ...

# %%
df['Runs']
# Out:
# 0     6996
# 1     1184
# 2     1485
# 3     2256
# 4     2190
#       ...
# 57    5357
# 58    9265
# 59    2122
# 60    2748
# 61    1296
# Name: Runs, Length: 62, dtype: int64

# %%
df.info() #information of overall dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Player      62 non-null     object
#  1   Duration    62 non-null     object
#  2   Matches     62 non-null     int64
#  3   Inns        62 non-null     int64
#  4   Not Out     62 non-null     int64
#  5   Runs        62 non-null     int64
#  6   HS          62 non-null     object
#  7   Ave         62 non-null     float64
#  8   Ball Faced  62 non-null     object
#  9   SR          62 non-null     object
#  10  100         62 non-null     int64
#  11  50          62 non-null     int64
#  12  0           62 non-null     object
#  13  4s          62 non-null     int64
#  14  6s          62 non-null     int64
# dtypes: float64(1), int64(8), object(6)
# memory usage: 7.4+ KB

# %% [markdown]
# ## Information of overall dataframe #nan=not a null

# %%
df.isnull()
# Out:
#     Player  Duration  Matches   Inns  Not Out   Runs     HS    Ave  \
# 0    False     False    False  False    False  False  False  False
# 1    False     False    False  False    False  False  False  False
# 2    False     False    False  False    False  False  False  False
# 3    False     False    False  False    False  False  False  False
# 4    False     False    False  False    False  False  False  False
# ..     ...       ...      ...    ...      ...    ...    ...    ...
# 57   False     False    False  False    False  False  False  False
# 58   False     False    False  False    False  False  False  False
# 59   False     False    False  False    False  False  False  False
# 60   False     False    False  False    False  False  False  False
# 61   False     False    False  False    False  False  False  False
#
#     Ball Faced     SR    100     50      0     4s     6s
# 0        False  False  False  False  False  False  False
# ...

# %% [markdown]
# ## To find null values

# %%
df.isnull().any()
# Out:
# Player        False
# Duration      False
# Matches       False
# Inns          False
# Not Out       False
# Runs          False
# HS            False
# Ave           False
# Ball Faced    False
# SR            False
# 100           False
# 50            False
# 0             False
# 4s            False
# 6s            False
# dtype: bool

# %% [markdown]
# ## To find duplicate rows:

# %%
df.duplicated() #To find Duplicate Rows
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 57    False
# 58    False
# 59    False
# 60    False
# 61    False
# Length: 62, dtype: bool

# %%
df
# Out:
#                Player   Duration  Matches  Inns  Not Out  Runs    HS    Ave  \
# 0    DG Bradman (AUS)  1928-1948       52    80       10  6996   334  99.94
# 1    PHKD Mendis (SL)  2022-2025       12    21        2  1184  182*  62.31
# 2      AC Voges (AUS)  2015-2016       20    31        7  1485  269*  61.87
# 3     RG Pollock (SA)  1963-1970       23    41        4  2256   274  60.97
# 4     GA Headley (WI)  1930-1954       22    40        4  2190  270*  60.83
# ..                ...        ...      ...   ...      ...   ...   ...    ...
# 57   KD Walters (AUS)  1965-1981       74   125       14  5357   250  48.26
# 58  GC Smith (ICC/SA)  2002-2014      117   205       13  9265   277  48.25
# 59  WH Ponsford (AUS)  1924-1934       29    48        4  2122   266  48.22
# 60    SJ McCabe (AUS)  1930-1938       39    62        5  2748   232  48.21
# 61   DR Jardine (ENG)  1928-1934       22    33        6  1296   127  48.00
#
#    Ball Faced     SR  100  50   0    4s  6s
# ...

# %% [markdown]
# ## To print Players dataframe

# %%
df['Player']
# Out:
# 0      DG Bradman (AUS)
# 1      PHKD Mendis (SL)
# 2        AC Voges (AUS)
# 3       RG Pollock (SA)
# 4       GA Headley (WI)
#             ...
# 57     KD Walters (AUS)
# 58    GC Smith (ICC/SA)
# 59    WH Ponsford (AUS)
# 60      SJ McCabe (AUS)
# 61     DR Jardine (ENG)
# Name: Player, Length: 62, dtype: object

# %% [markdown]
# ## To check first 5 rows by default

# %%
df.head(2)
# Out:
#              Player   Duration  Matches  Inns  Not Out  Runs    HS    Ave  \
# 0  DG Bradman (AUS)  1928-1948       52    80       10  6996   334  99.94
# 1  PHKD Mendis (SL)  2022-2025       12    21        2  1184  182*  62.31
#
#   Ball Faced     SR  100  50  0   4s  6s
# 0      9800+   58.6   29  13  7  626   6
# 1       1839  64.38    5   4  -  123  23

# %% [markdown]
# ## To print last value of dataframe

# %%
df.tail()#first 5 rows from bottom
# Out:
#                Player   Duration  Matches  Inns  Not Out  Runs   HS    Ave  \
# 57   KD Walters (AUS)  1965-1981       74   125       14  5357  250  48.26
# 58  GC Smith (ICC/SA)  2002-2014      117   205       13  9265  277  48.25
# 59  WH Ponsford (AUS)  1924-1934       29    48        4  2122  266  48.22
# 60    SJ McCabe (AUS)  1930-1938       39    62        5  2748  232  48.21
# 61   DR Jardine (ENG)  1928-1934       22    33        6  1296  127  48.00
#
#    Ball Faced     SR  100  50   0    4s  6s
# 57      8662+  49.16   15  33   4   525  23
# 58      15525  59.67   27  38  11  1165  24
# 59      3118+  44.77    7   6   1   119   0
# 60      3217+  60.02    6  13   4   241   5
# 61      2110+  25.59    1  10   2    53   0

# %%
df['Player']
# Out:
# 0      DG Bradman (AUS)
# 1      PHKD Mendis (SL)
# 2        AC Voges (AUS)
# 3       RG Pollock (SA)
# 4       GA Headley (WI)
#             ...
# 57     KD Walters (AUS)
# 58    GC Smith (ICC/SA)
# 59    WH Ponsford (AUS)
# 60      SJ McCabe (AUS)
# 61     DR Jardine (ENG)
# Name: Player, Length: 62, dtype: object

# %% [markdown]
# ## To Split values from dataframe

# %%
df['Country']=df['Player'].str.split(pat='(').str[1] #df=dataframe

# %%
df['Country']=df['Country'].str.split(pat=')').str[0]

# %%
df
# Out:
#                Player   Duration  Matches  Inns  Not Out  Runs    HS    Ave  \
# 0    DG Bradman (AUS)  1928-1948       52    80       10  6996   334  99.94
# 1    PHKD Mendis (SL)  2022-2025       12    21        2  1184  182*  62.31
# 2      AC Voges (AUS)  2015-2016       20    31        7  1485  269*  61.87
# 3     RG Pollock (SA)  1963-1970       23    41        4  2256   274  60.97
# 4     GA Headley (WI)  1930-1954       22    40        4  2190  270*  60.83
# ..                ...        ...      ...   ...      ...   ...   ...    ...
# 57   KD Walters (AUS)  1965-1981       74   125       14  5357   250  48.26
# 58  GC Smith (ICC/SA)  2002-2014      117   205       13  9265   277  48.25
# 59  WH Ponsford (AUS)  1924-1934       29    48        4  2122   266  48.22
# 60    SJ McCabe (AUS)  1930-1938       39    62        5  2748   232  48.21
# 61   DR Jardine (ENG)  1928-1934       22    33        6  1296   127  48.00
#
#    Ball Faced     SR  100  50   0    4s  6s Country
# ...

# %%
df['Duration']
# Out:
# 0     1928-1948
# 1     2022-2025
# 2     2015-2016
# 3     1963-1970
# 4     1930-1954
#         ...
# 57    1965-1981
# 58    2002-2014
# 59    1924-1934
# 60    1930-1938
# 61    1928-1934
# Name: Duration, Length: 62, dtype: object

# %%
df['Player']=df['Player'].str.split(pat='(').str[0]

# %%
df
# Out:
#           Player   Duration  Matches  Inns  Not Out  Runs    HS    Ave  \
# 0    DG Bradman   1928-1948       52    80       10  6996   334  99.94
# 1   PHKD Mendis   2022-2025       12    21        2  1184  182*  62.31
# 2      AC Voges   2015-2016       20    31        7  1485  269*  61.87
# 3    RG Pollock   1963-1970       23    41        4  2256   274  60.97
# 4    GA Headley   1930-1954       22    40        4  2190  270*  60.83
# ..           ...        ...      ...   ...      ...   ...   ...    ...
# 57   KD Walters   1965-1981       74   125       14  5357   250  48.26
# 58     GC Smith   2002-2014      117   205       13  9265   277  48.25
# 59  WH Ponsford   1924-1934       29    48        4  2122   266  48.22
# 60    SJ McCabe   1930-1938       39    62        5  2748   232  48.21
# 61   DR Jardine   1928-1934       22    33        6  1296   127  48.00
#
#    Ball Faced     SR  100  50   0    4s  6s Country
# 0       9800+   58.6   29  13   7   626   6     AUS
# ...

# %%
df['Duration']=df['Player'].str.split(pat='(')

# %%
df['Duration']
# Out:
# 0      [DG Bradman ]
# 1     [PHKD Mendis ]
# 2        [AC Voges ]
# 3      [RG Pollock ]
# 4      [GA Headley ]
#            ...
# 57     [KD Walters ]
# 58       [GC Smith ]
# 59    [WH Ponsford ]
# 60      [SJ McCabe ]
# 61     [DR Jardine ]
# Name: Duration, Length: 62, dtype: object

# %%
df['Player']=df['Player'].str.split(pat='(').str[0]

# %%
df
# Out:
#           Player        Duration  Matches  Inns  Not Out  Runs    HS    Ave  \
# 0    DG Bradman    [DG Bradman ]       52    80       10  6996   334  99.94
# 1   PHKD Mendis   [PHKD Mendis ]       12    21        2  1184  182*  62.31
# 2      AC Voges      [AC Voges ]       20    31        7  1485  269*  61.87
# 3    RG Pollock    [RG Pollock ]       23    41        4  2256   274  60.97
# 4    GA Headley    [GA Headley ]       22    40        4  2190  270*  60.83
# ..           ...             ...      ...   ...      ...   ...   ...    ...
# 57   KD Walters    [KD Walters ]       74   125       14  5357   250  48.26
# 58     GC Smith      [GC Smith ]      117   205       13  9265   277  48.25
# 59  WH Ponsford   [WH Ponsford ]       29    48        4  2122   266  48.22
# 60    SJ McCabe     [SJ McCabe ]       39    62        5  2748   232  48.21
# 61   DR Jardine    [DR Jardine ]       22    33        6  1296   127  48.00
#
#    Ball Faced     SR  100  50   0    4s  6s Country
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Player      62 non-null     object
#  1   Duration    62 non-null     object
#  2   Matches     62 non-null     int64
#  3   Inns        62 non-null     int64
#  4   Not Out     62 non-null     int64
#  5   Runs        62 non-null     int64
#  6   HS          62 non-null     object
#  7   Ave         62 non-null     float64
#  8   Ball Faced  62 non-null     object
#  9   SR          62 non-null     object
#  10  100         62 non-null     int64
#  11  50          62 non-null     int64
#  12  0           62 non-null     object
#  13  4s          62 non-null     int64
#  14  6s          62 non-null     int64
#  15  Country     62 non-null     object
# dtypes: float64(1), int64(8), object(7)
# memory usage: 7.9+ KB

# %%
df['HS']=df['HS'].str.split(pat='*').str[0]

# %%
df['HS']
# Out:
# 0     334
# 1     182
# 2     269
# 3     274
# 4     270
#      ...
# 57    250
# 58    277
# 59    266
# 60    232
# 61    127
# Name: HS, Length: 62, dtype: object

# %%
df['HS']=df['HS'].astype('int')

# %%
df['HS'].dtype
# Out:
# dtype('int64')

# %%
df[df['HS']<=190]   #Print HS(High Score) Below 190.
# Out:
#              Player           Duration  Matches  Inns  Not Out  Runs   HS  \
# 1      PHKD Mendis      [PHKD Mendis ]       12    21        2  1184  182
# 18    GE Tyldesley     [GE Tyldesley ]       14    20        2   990  122
# 20        CA Davis         [CA Davis ]       15    29        5  1301  183
# 48         CP Mead          [CP Mead ]       17    26        2  1185  182
# 52        KC Bland         [KC Bland ]       21    39        5  1669  144
# 53      B Mitchell       [B Mitchell ]       42    80        9  3471  189
# 54  Hon.FS Jackson   [Hon.FS Jackson ]       20    33        4  1415  144
# 61      DR Jardine       [DR Jardine ]       22    33        6  1296  127
#
#       Ave Ball Faced     SR  100  50  0   4s  6s Country
# 1   62.31       1839  64.38    5   4  -  123  23      SL
# 18  55.00       178+  29.21    3   6  2   37   2     ENG
# 20  54.20       665+  35.48    4   4  1   65   1      WI
# 48  49.37       619+  30.04    4   3  3   38   0     ENG
# ...
